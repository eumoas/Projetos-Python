# %% [markdown]
# <a href="https://colab.research.google.com/github/eumoas/Projetos-Python/blob/main/Missing_Values.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df1 = pd.DataFrame({'aluno': ["Joel", "Gabriel", "Carlos","Joana", "Karina"],
                   "idade": [25, 52, 14, 12, 14]})

# %%
df1
# Out:
#      aluno  Idade
# 0     Joel     25
# 1  Gabriel     52
# 2   Carlos     14
# 3    Joana     12
# 4   Karina     14

# %%
df2 = pd.DataFrame({'nome': ['Joel', 'Gabriel'],
                    "altura": [1.60, 1.45]})

# %%
df2
# Out:
#       nome  altura
# 0     Joel    1.60
# 1  Gabriel    1.45

# %%
                  df1e2 = pd.merge (df1,
                  df2,
                  how = 'left',
                  left_on = 'aluno',
                  right_on = 'nome')\
                  .drop('nome', axis=1)

# %%
df1e2
# Out:
#      aluno  idade  altura
# 0     Joel     25    1.60
# 1  Gabriel     52    1.45
# 2   Carlos     14     NaN
# 3    Joana     12     NaN
# 4   Karina     14     NaN

# %%
df1e2.isna()
# Out:
#    aluno  idade  altura
# 0  False  False   False
# 1  False  False   False
# 2  False  False    True
# 3  False  False    True
# 4  False  False    True

# %%
df1e2.isna().sum()
# Out:
# aluno     0
# idade     0
# altura    3
# dtype: int64

# %%
df1e2.fillna(df1e2['altura'].mean())
# Out:
#      aluno  idade  altura
# 0     Joel     25   1.600
# 1  Gabriel     52   1.450
# 2   Carlos     14   1.525
# 3    Joana     12   1.525
# 4   Karina     14   1.525
